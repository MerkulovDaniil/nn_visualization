# %% [markdown]
# <a href="https://colab.research.google.com/drive/1HwwHbwYvMYujCgNv6mn3EiP2WGa-TJRr?usp=sharing" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys


RUNNING_IN_COLAB = 'google.colab' in sys.modules
if RUNNING_IN_COLAB:
    pass
    # Cloning files from the repo
    # os.system('!rm -rf ./*; git clone https://github.com/MerkulovDaniil/nn_visualization.git foo --hard; mv foo/* foo/.git* .; rm -rf foo')
else:
    print('🤖 Please, visit https://colab.research.google.com/drive/1HwwHbwYvMYujCgNv6mn3EiP2WGa-TJRr?usp=sharing to download files in order to run it locally')
# Out:
# 🤖 Please, visit https://colab.research.google.com/drive/1HwwHbwYvMYujCgNv6mn3EiP2WGa-TJRr?usp=sharing to download files in order to run it locally

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from intevis import Intevis


iv = Intevis()
iv.set_model(name='vgg13') # 'vgg13' # 'vgg16' # torch.hub.list('pytorch/vision', force_reload=True)
iv.set_image(link='https://specials-images.forbesimg.com/imageserve/5db4c7b464b49a0007e9dfac/960x0.jpg?fit=scale')
# Out:
# Using cache found in /Users/andrei/.cache/torch/hub/pytorch_vision_main

# %% [markdown]
# ## Architecture

# %%
iv.run_ar()

# %% [markdown]
# ## Activation Maximization

# %%
iv.run_am(layer=2, filter=10, lr=0.5, iters=2, is_random=True) # iters нужно брать больше
iv.plot_am()
# Out:
# /home/es/python_venv/pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py:1025: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "

# %%
iv.run_am(layer=2, filter=10, lr=0.5, iters=2, is_random=False)
iv.plot_am()

# %% [markdown]
# ## Saliency Map

# %%
iv.run_sm()
iv.plot_sm()

# %% [markdown]
# ## Integrated Gradients

# %%
iv.run_ig(steps=3) # steps нужно брать больше
iv.plot_ig()

# %% [markdown]
# ## Score-CAM

# %%
iv.run_sc()
iv.plot_sc()
# Out:
# /home/es/Projects/nn_vis2/attribution/sc.py:52: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   logit = F.softmax(logit)
# /home/es/Projects/nn_vis2/attribution/sc.py:86: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(output)

# %% [markdown]
# ## Архитектура
